# %%
# Import dependencies
import pandas as pd

# Read csv
geo_df = pd.read_csv("Resources/olist_geolocation_dataset.csv")
geo_df.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %%
geo_df.value_counts()
# Out:
# geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  geolocation_city  geolocation_state
# 88220                        -27.102099       -48.629613       itapema           SC                   314
# 6414                         -23.495901       -46.874687       barueri           SP                   189
#                              -23.490618       -46.869004       barueri           SP                   127
# 5145                         -23.506049       -46.717377       sao paulo         SP                   126
# 22620                        -23.005514       -43.375964       rio de janeiro    RJ                   102
#                                                                                                      ...
# 18150                        -23.660570       -47.216268       ibiuna            SP                     1
#                              -23.660564       -47.223828       ibiuna            SP                     1
# ...

# %%
# Dropping Duplicates
geo_df.drop_duplicates()
# Out:
#          geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                               1037       -23.545621       -46.639292
# 1                               1046       -23.546081       -46.644820
# 2                               1046       -23.546129       -46.642951
# 3                               1041       -23.544392       -46.639499
# 4                               1035       -23.541578       -46.641607
# ...                              ...              ...              ...
# 1000155                        99965       -28.180655       -52.034367
# 1000156                        99950       -28.072188       -52.011272
# 1000157                        99950       -28.068864       -52.012964
# 1000158                        99950       -28.068639       -52.010705
# 1000161                        99980       -28.388932       -51.846871
#
#         geolocation_city geolocation_state
# 0              sao paulo                SP
# ...

# %%
clean_geo_df = geo_df.drop_duplicates(subset=['geolocation_zip_code_prefix'])
clean_geo_df
# Out:
#         geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                              1037       -23.545621       -46.639292
# 1                              1046       -23.546081       -46.644820
# 3                              1041       -23.544392       -46.639499
# 4                              1035       -23.541578       -46.641607
# 5                              1012       -23.547762       -46.635361
# ...                             ...              ...              ...
# 999774                        99955       -28.107588       -52.144019
# 999780                        99970       -28.345143       -51.876926
# 999786                        99910       -27.863500       -52.084760
# 999803                        99920       -27.858716       -52.300403
# 999846                        99952       -28.160371       -51.936922
#
#             geolocation_city geolocation_state
# 0                  sao paulo                SP
# ...
